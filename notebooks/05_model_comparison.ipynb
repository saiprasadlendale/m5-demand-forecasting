# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error
import pandas as pd

# %%
def mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
results = pd.DataFrame({
    "Model": ["SARIMA"],
    "MAE": [mean_absolute_error(test['Weekly_Sales'], sarima_forecast)],
    "RMSE": [np.sqrt(mean_squared_error(test['Weekly_Sales'], sarima_forecast))],
    "MAPE": [mape(test['Weekly_Sales'], sarima_forecast)]
})

results
# Out:
#     Model      MAE         RMSE       MAPE
# 0  SARIMA  1600.15  1883.236323  38.306108

# %%
results = pd.DataFrame({
    "Model": ["SARIMA"],
    "MAE": [mean_absolute_error(test['Weekly_Sales'], sarima_forecast)],
    "RMSE": [np.sqrt(mean_squared_error(test['Weekly_Sales'], sarima_forecast))],
    "MAPE": [mape(test['Weekly_Sales'], sarima_forecast)]
})

results

# %%
results.to_csv("metrics.csv", index=False)

# %%
results = pd.DataFrame({
    "Model": ["SARIMA"],
    "MAE": [mean_absolute_error(test['Weekly_Sales'], sarima_forecast)],
    "RMSE": [np.sqrt(mean_squared_error(test['Weekly_Sales'], sarima_forecast))],
    "MAPE": [mape(test['Weekly_Sales'], sarima_forecast)]
})

results
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3732427406.py in <cell line: 0>()
#       2     "Model": ["SARIMA"],
#       3     "MAE": [mean_absolute_error(test['Weekly_Sales'], sarima_forecast)],
# ----> 4     "RMSE": [mean_squared_error(test['Weekly_Sales'], sarima_forecast, squared=False)],
#       5     "MAPE": [mape(test['Weekly_Sales'], sarima_forecast)]
#       6 })
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     192
#     193             # Map *args/**kwargs to the function signature
# --> 194             params = func_sig.bind(*args, **kwargs)
#     195             params.apply_defaults()
#     196
#
# /usr/lib/python3.12/inspect.py in bind(self, *args, **kwargs)
#    3278         if the passed arguments can not be bound.
#    3279         """
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(test.index, test['Weekly_Sales'], label='Actual Weekly Sales')
plt.plot(sarima_forecast.index, sarima_forecast, label='SARIMA Forecast')
plt.title('SARIMA Model Performance: Actual vs. Forecasted Weekly Sales')
plt.xlabel('Date')
plt.ylabel('Weekly Sales')
plt.legend()
plt.grid(True)
plt.show()
